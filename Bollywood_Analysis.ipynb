# %% [markdown]
# #### Author: Balaji Kartheek
#
# ### Meta-Data of the Bollywood Dataset:
#
# #### SINo - Identifier for the movies.
# #### Release Date - Date on which the movie was released.
# #### MovieName - Name of the movie.
# #### ReleaseTime - Mentions special time of release. LW (Long weekend), FS (Festive Season), HS (Holiday Season), N (Normal).
# #### Genre – Genre of the film such as Romance, Thriller, Action, Comedy, etc
# #### Budget – Movie creation budget
# #### BoxOfficeCollection – Box office collection
# #### YoutubeViews – Number of views of the YouTube trailers
# #### YoutubeLikes – Number of likes of the YouTube trailers
# #### YoutubeDislikes – Number of dislikes of the YouTube trailers

# %%
#importing the libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### importing the dataset using the read_csv function

# %%
data = pd.read_csv("bollywood.csv")
# link for bollywood movies dataset is : https://www.kaggle.com/datasets/mitesh58/bollywood-movie-dataset

# %% [markdown]
# ### visualizing the data

# %%
data.head()
# Out:
#    SlNo Release Date           MovieName ReleaseTime      Genre  Budget  \
# 0     1    18-Apr-14            2 States          LW    Romance      36
# 1     2     4-Jan-13        Table No. 21           N  Thriller       10
# 2     3    18-Jul-14  Amit Sahni Ki List           N     Comedy      10
# 3     4     4-Jan-13    Rajdhani Express           N     Drama        7
# 4     5     4-Jul-14        Bobby Jasoos           N     Comedy      18
#
#    BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0               104.00       8576361         26622             2527
# 1                12.00       1087320          1129              137
# 2                 4.00        572336           586               54
# 3                 0.35         42626            86               19
# 4                10.80       3113427          4512             1224

# %% [markdown]
# ### 1. How many records are present in the dataset?

# %%
print(data["SlNo"].value_counts())
data.info()
# Out:
# 1      1
# 95     1
# 97     1
# 98     1
# 99     1
#       ..
# 51     1
# 52     1
# 53     1
# 54     1
# 149    1
# Name: SlNo, Length: 149, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    object
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 11.8+ KB

# %%
data.shape[0] # this also gives the number of records in the dataset

# %% [markdown]
# ### here we can see that there are 149 records in the dataset entries ranging from 0 to 148

# %% [markdown]
# ### 2. How many movies got released in each genre? Sort number of releases in each genre in descending order

# %%
data["Genre"] = data["Genre"].str.strip()
data["Genre"].value_counts()
# Out:
# Comedy      36
# Drama       35
# Thriller    29
# Romance     25
# Action      24
# Name: Genre, dtype: int64

# %% [markdown]
# ### In the above table we can see that there are more comedy movies released and less Action,Thriller movies

# %% [markdown]
# ### 3. Which genre had highest number of releases?

# %%
data["Genre"].value_counts()   # value_counts() function is used to count the number of unique values in various types
# Out:
# Comedy      36
# Drama       35
# Thriller    29
# Romance     25
# Action      24
# Name: Genre, dtype: int64

# %%
highest_genre_releases = data["Genre"].value_counts().max()
highest_genre_releases

# 36 belongs to the comedy Genre
# Out:
# 36

# %% [markdown]
# ### here we can see that highest_genre_releases is high in COMEDY i.e (number of release movies is 36)

# %% [markdown]
# ### 4.How many movies in each genre got released in different release times like long weekend, festive season, etc. (Note: Do a cross tabulation between Genre and ReleaseTime.)

# %%
data
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 0       1    18-Apr-14                     2 States          LW   Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N    Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N    Comedy
# ..    ...          ...                          ...         ...       ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N    Comedy
# 145   146    13-Mar-15                         NH10           N  Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148    20-Mar-15                     Hunterrr           N    Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# ...

# %%
comedy_data = data[data["Genre"]=="Comedy"]
comedy_data
# Out:
#      SlNo Release Date                    MovieName ReleaseTime   Genre  \
# 2       3    18-Jul-14           Amit Sahni Ki List           N  Comedy
# 4       5     4-Jul-14                 Bobby Jasoos           N  Comedy
# 6       7    19-Sep-14                Daawat-E-Ishq           N  Comedy
# 7       8    11-Jan-13   Matru Ki Bijlee Ka Mandola           N  Comedy
# 8       9    10-Jan-14                 Dedh Ishqiya          LW  Comedy
# 14     15     8-Aug-14                Entertainment           N  Comedy
# 17     18     6-Jun-14                   Filmistaan          HS  Comedy
# 18     19    12-Sep-14                Finding Fanny           N  Comedy
# 19     20    13-Jun-14                        Fugly          HS  Comedy
# 39     40    20-Jun-14                   Humshakals          HS  Comedy
# 46     47    15-Mar-13           Mere Dad Ki Maruti           N  Comedy
# 47     48    15-Mar-13                    Jolly LLB           N  Comedy
# ...

# %%
comedy_data["ReleaseTime"].value_counts()
# Out:
# N     23
# LW     5
# HS     5
# FS     3
# Name: ReleaseTime, dtype: int64

# %% [markdown]
# ### for Comedy Genre ->
# #### In Normal days =there are 23 movie releases
# #### In HoliDay Season =there are 5 movie releases
# #### In Long Weekends =there are 5 movie releases
# #### In Festive Season =there are 3 movie releases

# %%
romance_data = data[data["Genre"]=="Romance"]
romance_data
# Out:
#      SlNo Release Date                  MovieName ReleaseTime    Genre  \
# 0       1    18-Apr-14                   2 States          LW  Romance
# 11     12    18-Jan-13                     Inkaar           N  Romance
# 12     13    27-Jun-14                 Ek Villain          HS  Romance
# 24     25    21-Nov-14               Happy Ending           N  Romance
# 32     33    23-May-14                  Heropanti          HS  Romance
# 37     38    11-Jul-14  Humpty Sharma Ki Dulhania           N  Romance
# 42     43    19-Sep-14                 Khoobsurat           N  Romance
# 45     46    14-Nov-14                   Kill Dil           N  Romance
# 50     51     4-Jul-14      Lekar Hum Deewana Dil           N  Romance
# 64     65    26-Apr-13                 Aashiqui 2           N  Romance
# 66     67    31-Jan-14                 One by Two           N  Romance
# 67     68     2-May-14               Purani Jeans          HS  Romance
# ...

# %%
romance_data["ReleaseTime"].value_counts()
# Out:
# N     15
# LW     4
# FS     3
# HS     3
# Name: ReleaseTime, dtype: int64

# %% [markdown]
# ### for Romance Genre ->
# #### In Normal days =there are 15 movie releases
# #### In HoliDay Season =there are 3 movie releases
# #### In Long Weekends =there are 4 movie releases
# #### In Festive Season =there are 3 movie releases

# %%
drama_data = data[data["Genre"]=="Drama"]
drama_data
# Out:
#      SlNo Release Date                         MovieName ReleaseTime  Genre  \
# 3       4     4-Jan-13                  Rajdhani Express           N  Drama
# 5       6    30-May-14                        Citylights          HS  Drama
# 9      10    11-Jan-13                         Gangoobai           N  Drama
# 23     24     2-Oct-14                            Haider          FS  Drama
# 25     26     8-Feb-13                        Special 26           N  Drama
# 26     27    24-Oct-14                    Happy New Year          LW  Drama
# 27     28     8-Feb-13         ABCD _ Any Body Can Dance           N  Drama
# 29     30     9-May-14                      Hawaa Hawaai          HS  Drama
# 33     34    22-Feb-13                       Kai Po Che!           N  Drama
# 34     35    21-Feb-14                           Highway           N  Drama
# 40     41     8-Mar-13  Saheb, Biwi Aur Gangster Returns          FS  Drama
# ...

# %%
drama_data["ReleaseTime"].value_counts()
# Out:
# N     24
# HS     6
# FS     4
# LW     1
# Name: ReleaseTime, dtype: int64

# %% [markdown]
# ### for Drama Genre ->
# #### In Normal days =there are 24 movie releases
# #### In HoliDay Season =there are 6 movie releases
# #### In Long Weekends =there are 1 movie releases
# #### In Festive Season =there are 4 movie release

# %%
thriller_data = data[data["Genre"]=="Thriller"]
thriller_data
# Out:
#      SlNo Release Date                             MovieName ReleaseTime  \
# 1       2     4-Jan-13                          Table No. 21           N
# 16     17    25-Jan-13                                Race 2          LW
# 20     21     1-Feb-13                                 David           N
# 28     29    18-Jul-14                          Hate Story 2           N
# 30     31     7-Feb-14                             Heartless           N
# 31     32    15-Feb-13                              Murder 3          FS
# 38     39     1-Mar-13                  The Attacks of 26/11           N
# 44     45    15-Mar-13                                    3G           N
# 51     52    22-Mar-13                                 Aatma           N
# 53     54    22-Mar-13                              Sona Spa           N
# 62     63    19-Apr-13                         Ek Thi Daayan          FS
# 68     69     3-May-13                    Shootout at Wadala           N
# ...

# %%
thriller_data["ReleaseTime"].value_counts()
# Out:
# N     22
# FS     4
# LW     2
# HS     1
# Name: ReleaseTime, dtype: int64

# %% [markdown]
# ### for Thriller Genre ->
# #### In Normal days =there are 22 movie releases
# #### In HoliDay Season =there are 1 movie releases
# #### In Long Weekends =there are 2 movie releases
# #### In Festive Season =there are 4 movie releases

# %%
action_data = data[data["Genre"]=="Action"]
action_data
# Out:
#      SlNo Release Date                MovieName ReleaseTime   Genre  Budget  \
# 10     11    28-Mar-14              Dishkiyaoon           N  Action      28
# 13     14    18-Jan-13            Mumbai Mirror           N  Action       4
# 15     16    18-Jan-13                  Bandook           N  Action       4
# 21     22     7-Mar-14              Gulaab Gang           N  Action      27
# 22     23    14-Feb-14                   Gunday           N  Action      50
# 35     36    22-Feb-13          Zilla Ghaziabad           N  Action      36
# 36     37     6-Jun-14                  Holiday          HS  Action      50
# 41     42    24-Jan-14                   Jai Ho           N  Action     120
# 43     44    25-Jul-14                     Kick           N  Action     100
# 48     49     9-May-14             Koyelaanchal          HS  Action       8
# 54     55    29-Mar-13               Himmatwala           N  Action      50
# ...

# %%
action_data["ReleaseTime"].value_counts()
# Out:
# N     15
# FS     3
# LW     3
# HS     3
# Name: ReleaseTime, dtype: int64

# %% [markdown]
# ### for Action Genre ->
# #### In Normal days =there are 15 movie releases
# #### In HoliDay Season =there are 3 movie releases
# #### In Long Weekends =there are 3 movie releases
# #### In Festive Season =there are 3 movie releases

# %%
genre_release_time = pd.crosstab(data.Genre,data.ReleaseTime, margins =True,margins_name ="Total")
genre_release_time
# Out:
# ReleaseTime  FS  HS  LW   N  Total
# Genre
# Action        3   3   3  15     24
# Comedy        3   5   5  23     36
# Drama         4   6   1  24     35
# Romance       3   3   4  15     25
# Thriller      4   1   2  22     29
# Total        17  18  15  99    149

# %% [markdown]
# #### Above Table is the crosstab between the Release Time and Genre

# %% [markdown]
# ### 5.Which month of the year, maximum number movie releases are seen? (Note: Extract a new column called month from ReleaseDate column.)

# %%
data["Release Date"].value_counts()
# Out:
# 9-May-14     5
# 18-Jul-14    3
# 28-Mar-14    3
# 26-Jul-13    3
# 7-Mar-14     3
#             ..
# 13-Jun-14    1
# 7-Nov-14     1
# 13-Sep-13    1
# 14-Feb-14    1
# 18-Apr-14    1
# Name: Release Date, Length: 102, dtype: int64

# %%
data['Release Date'] = pd.to_datetime(data['Release Date'])   # to_datetime converts the string to a date time format

# %%
data["Year"] = data["Release Date"].dt.year   # extracts the year from the date

# %%
data["month"]=data["Release Date"].dt.month   # extracts the month from the date
data["month"]
# Out:
# 0      4
# 1      1
# 2      7
# 3      1
# 4      7
#       ..
# 144    2
# 145    3
# 146    3
# 147    3
# 148    5
# Name: month, Length: 149, dtype: int64

# %% [markdown]
# #### In the Above table in month column 1 refers to January and 2 refers to February and soon on for total of 12 months

# %%
data["month"].value_counts()
# Out:
# 1     20
# 3     19
# 5     18
# 2     16
# 7     16
# 4     11
# 6     10
# 9     10
# 11    10
# 10     9
# 8      8
# 12     2
# Name: month, dtype: int64

# %% [markdown]
# ### Here we can see that In Janauary month(1) there are more number of movie releases and in December there are less number of movie releases

# %%
year_2013 = data[data["Year"]==2013]
year_2014 = data[data["Year"]==2014]
year_2015 = data[data["Year"]==2015]
year_2013["month"].value_counts()
# Out:
# 7     9
# 1     8
# 3     8
# 2     6
# 5     6
# 10    6
# 4     5
# 6     5
# 9     5
# 11    5
# 8     4
# Name: month, dtype: int64

# %%
year_2014["month"].value_counts()
# Out:
# 5     12
# 3      8
# 1      7
# 7      7
# 2      6
# 4      6
# 6      5
# 9      5
# 11     5
# 8      4
# 10     3
# 12     2
# Name: month, dtype: int64

# %%
year_2015["month"].value_counts()
# Out:
# 1    5
# 2    4
# 3    3
# Name: month, dtype: int64

# %% [markdown]
# ### Here we can see that in the month of MAY 2014 there are more number of movie releases i.e 12 movies

# %% [markdown]
# ### 6. Which month of the year typically sees most releases of high budgeted movies, that is, movies with budget of 25 crore or more?

# %%
high_budget_data = data[data["Budget"]>=25]
high_budget_data
# Out:
#      SlNo Release Date                    MovieName ReleaseTime    Genre  \
# 0       1   2014-04-18                     2 States          LW  Romance
# 6       7   2014-09-19                Daawat-E-Ishq           N   Comedy
# 7       8   2013-01-11   Matru Ki Bijlee Ka Mandola           N   Comedy
# 8       9   2014-01-10                 Dedh Ishqiya          LW   Comedy
# 10     11   2014-03-28                  Dishkiyaoon           N   Action
# ..    ...          ...                          ...         ...      ...
# 139   140   2015-01-30                   Hawaizaada           N    Drama
# 141   142   2015-02-06                    Shamitabh           N    Drama
# 142   143   2015-02-13                          Roy          FS  Romance
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N   Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS   Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  \
# ...

# %%
year_2013 = high_budget_data[high_budget_data["Year"]==2013]
year_2014 = high_budget_data[high_budget_data["Year"]==2014]
year_2015 = high_budget_data[high_budget_data["Year"]==2015]
year_2013["month"].value_counts()
# Out:
# 7     5
# 8     4
# 9     4
# 2     3
# 11    3
# 1     2
# 3     2
# 5     2
# 6     2
# 10    2
# Name: month, dtype: int64

# %%
year_2014["month"].value_counts()
# Out:
# 2     4
# 3     4
# 4     4
# 1     3
# 6     3
# 8     3
# 11    3
# 10    2
# 12    2
# 5     1
# 7     1
# 9     1
# Name: month, dtype: int64

# %%
year_2015["month"].value_counts()
# Out:
# 1    3
# 2    2
# 3    1
# Name: month, dtype: int64

# %% [markdown]
# ### Here we can see that In the month of July of year 2013 typically sees most releases of high budgeted movies, that is, movies with budget of 25 crore or more

# %% [markdown]
# ### 7. Which are the top 10 movies with maximum return on investment (ROI)? Calculate return on investment (ROI) as (BoxOfficeCollection – Budget) / Budget.

# %%
data["ROI"] = (data["BoxOfficeCollection"] - data["Budget"])/(data["Budget"])

# %%
data
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 0       1   2014-04-18                     2 States          LW   Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N    Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N    Comedy
# ..    ...          ...                          ...         ...       ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N    Comedy
# 145   146   2015-03-13                         NH10           N  Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148   2015-03-20                     Hunterrr           N    Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  \
# ...

# %%
data[data["ROI"]==data["ROI"].max()]
# Out:
#     SlNo Release Date   MovieName ReleaseTime    Genre  Budget  \
# 64    65   2013-04-26  Aashiqui 2           N  Romance      12
#
#     BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  Year  \
# 64                110.0       2926673          4944              628  2013
#
#     month       ROI
# 64      4  8.166667

# %%
sort_ROI = data["ROI"].sort_values()
sort_ROI
# Out:
# 9     -0.995000
# 15    -0.977500
# 53    -0.976000
# 3     -0.950000
# 49    -0.928571
#          ...
# 87     6.240000
# 135    7.500000
# 132    7.514286
# 89     7.647059
# 64     8.166667
# Name: ROI, Length: 149, dtype: float64

# %%
top_10_ROI_movies = data.nlargest(n=10,columns=["ROI"])
top_10_ROI_movies
# Out:
#      SlNo Release Date                  MovieName ReleaseTime    Genre  \
# 64     65   2013-04-26                 Aashiqui 2           N  Romance
# 89     90   2014-12-19                         PK          HS    Drama
# 132   133   2013-09-13                Grand Masti          LW   Comedy
# 135   136   2013-09-20               The Lunchbox           N    Drama
# 87     88   2013-06-14                     Fukrey           N   Comedy
# 58     59   2014-09-05                   Mary Kom           N    Drama
# 128   129   2013-10-18                     Shahid          FS    Drama
# 37     38   2014-07-11  Humpty Sharma Ki Dulhania           N  Romance
# 101   102   2013-07-12         Bhaag Milkha Bhaag           N    Drama
# 115   116   2013-08-09            Chennai Express          FS   Comedy
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  \
# 64       12                110.0       2926673          4944              628
# ...

# %%
top_10_ROI_movies.loc[:, ["MovieName","ROI"]]
# Out:
#                      MovieName       ROI
# 64                  Aashiqui 2  8.166667
# 89                          PK  7.647059
# 132                Grand Masti  7.514286
# 135               The Lunchbox  7.500000
# 87                      Fukrey  6.240000
# 58                    Mary Kom  5.933333
# 128                     Shahid  5.666667
# 37   Humpty Sharma Ki Dulhania  5.500000
# 101         Bhaag Milkha Bhaag  4.466667
# 115            Chennai Express  4.266667

# %% [markdown]
# ### Above represents the top 10 movies list with maximum return on investment (ROI)

# %% [markdown]
# ### 8. Do the movies have higher ROI if they get released on festive seasons or long weekend? Calculate the average ROI for different release times.

# %%
data
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 0       1   2014-04-18                     2 States          LW   Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N    Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N    Comedy
# ..    ...          ...                          ...         ...       ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N    Comedy
# 145   146   2015-03-13                         NH10           N  Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148   2015-03-20                     Hunterrr           N    Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  \
# ...

# %%
data["ReleaseTime"].value_counts()
# Out:
# N     99
# HS    18
# FS    17
# LW    15
# Name: ReleaseTime, dtype: int64

# %%
normal_season = data[data["ReleaseTime"]=="N"]
normal_season
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N    Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N    Comedy
# 6       7   2014-09-19                Daawat-E-Ishq           N    Comedy
# ..    ...          ...                          ...         ...       ...
# 141   142   2015-02-06                    Shamitabh           N     Drama
# 144   145   2015-02-27           Dum Laga Ke Haisha           N    Comedy
# 145   146   2015-03-13                         NH10           N  Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148   2015-03-20                     Hunterrr           N    Comedy
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  \
# ...

# %%
Holiday_season = data[data["ReleaseTime"]=="HS"]
Holiday_season
# Out:
#      SlNo Release Date             MovieName ReleaseTime     Genre  Budget  \
# 5       6   2014-05-30            Citylights          HS     Drama       7
# 12     13   2014-06-27            Ek Villain          HS   Romance      35
# 17     18   2014-06-06            Filmistaan          HS    Comedy      10
# 19     20   2014-06-13                 Fugly          HS    Comedy      10
# 29     30   2014-05-09          Hawaa Hawaai          HS     Drama      11
# 32     33   2014-05-23             Heropanti          HS   Romance      21
# 36     37   2014-06-06               Holiday          HS    Action      50
# 39     40   2014-06-20            Humshakals          HS    Comedy      75
# 48     49   2014-05-09          Koyelaanchal          HS    Action       8
# 49     50   2014-05-02  Kya Dilli Kya Lahore          HS     Drama       7
# 55     56   2014-05-09             Manjunath          HS     Drama       3
# ...

# %%
Festive_season = data[data["ReleaseTime"]=="FS"]
Festive_season
# Out:
#      SlNo Release Date                             MovieName ReleaseTime  \
# 23     24   2014-10-02                                Haider          FS
# 31     32   2013-02-15                              Murder 3          FS
# 40     41   2013-03-08      Saheb, Biwi Aur Gangster Returns          FS
# 62     63   2013-04-19                         Ek Thi Daayan          FS
# 92     93   2014-10-02                             Bang Bang          FS
# 106   107   2014-03-14                          Bewakoofiyan          FS
# 115   116   2013-08-09                       Chennai Express          FS
# 116   117   2013-08-15  Once Upon Ay Time In Mumbai Dobaara!          FS
# 119   120   2013-11-01                              Krrish 3          FS
# 121   122   2013-11-08                               Satya 2          FS
# 122   123   2013-11-15                                 Rajjo          FS
# 125   126   2013-10-11                     War Chhod Na Yaar          FS
# ...

# %%
LongWeekend = data[data["ReleaseTime"]=="LW"]
LongWeekend
# Out:
#      SlNo Release Date                MovieName ReleaseTime     Genre  Budget  \
# 0       1   2014-04-18                 2 States          LW   Romance      36
# 8       9   2014-01-10             Dedh Ishqiya          LW    Comedy      31
# 16     17   2013-01-25                   Race 2          LW  Thriller      60
# 26     27   2014-10-24           Happy New Year          LW     Drama     125
# 52     53   2014-04-04           Main Tera Hero          LW    Comedy      40
# 59     60   2013-04-12           Nautanki Saala          LW    Comedy       9
# 61     62   2013-04-12  Commando-A One Man Army          LW    Action      22
# 78     79   2014-08-15          Singham Returns          LW    Action      90
# 80     81   2013-05-24           Ishkq in Paris          LW   Romance      15
# 83     84   2014-01-10                 Yaariyan          LW   Romance      19
# 96     97   2013-10-02                 Besharam          LW    Comedy      85
# ...

# %%
ROI_season = pd.DataFrame(
{
    "season": ["Normal","Festive Season","Holiday Season","Long Weekend"],
    "Total_ROI":[normal_season["ROI"].sum(),Festive_season["ROI"].sum(),Holiday_season["ROI"].sum(),LongWeekend["ROI"].sum()]
})
ROI_season
# Out:
#            season  Total_ROI
# 0          Normal  65.114441
# 1  Festive Season  16.555504
# 2  Holiday Season  15.315602
# 3    Long Weekend  16.908080

# %% [markdown]
# ### From the Above DataFrame we can see that In LongWeekend season there is more ROI(16.908080) than in Festive_season(16.555504)

# %%
ROI_season["Average_ROI"]=[normal_season["ROI"].mean(),Festive_season["ROI"].mean(),Holiday_season["ROI"].mean(),LongWeekend["ROI"].mean()]
ROI_season
# Out:
#            season  Total_ROI  Average_ROI
# 0          Normal  65.114441     0.657722
# 1  Festive Season  16.555504     0.973853
# 2  Holiday Season  15.315602     0.850867
# 3    Long Weekend  16.908080     1.127205

# %% [markdown]
# ### Above Table gives the Average ROI for different Release Time also

# %% [markdown]
# ### 9. Is there a correlation between box office collection and YouTube likes? Is the correlation positive or negative?

# %%
BoxOfficeCollection =data["BoxOfficeCollection"]
YoutubeLikes = data["YoutubeLikes"]
correlation_collection_likes = BoxOfficeCollection.corr(YoutubeLikes)
correlation_collection_likes
# Out:
# 0.6825165877731297

# %% [markdown]
# ### The correlation between box office collection and YouTube likes is 0.6825165877731297 which is positive in nature and also

# %% [markdown]
# ### 10. Which genre of movies typically sees more YouTube likes? Draw boxplots for each genre of movies to compare

# %%
data
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 0       1   2014-04-18                     2 States          LW   Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N    Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N    Comedy
# ..    ...          ...                          ...         ...       ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N    Comedy
# 145   146   2015-03-13                         NH10           N  Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148   2015-03-20                     Hunterrr           N    Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  \
# ...

# %%
data["Genre"].value_counts()
# Out:
# Comedy      36
# Drama       35
# Thriller    29
# Romance     25
# Action      24
# Name: Genre, dtype: int64

# %%
values =[]
comedy_data = data[data["Genre"]=="Comedy"]
likes_comedy_data = comedy_data["YoutubeLikes"].sum()
values.append(likes_comedy_data)
values
# Out:
# [172250]

# %%
romance_data = data[data["Genre"]== "Romance"]
likes_romance_data = romance_data["YoutubeLikes"].sum()
values.append(likes_romance_data)
values
# Out:
# [172250, 177241]

# %%
thriller_data = data[data["Genre"]== "Thriller"]
likes_thriller_data = thriller_data["YoutubeLikes"].sum()
values.append(likes_thriller_data)
values
# Out:
# [172250, 177241, 143312]

# %%
action_data = data[data["Genre"]== "Action"]
likes_action_data = action_data["YoutubeLikes"].sum()
values.append(likes_action_data)
values
# Out:
# [172250, 177241, 143312, 401873]

# %%
Drama_data = data[data["Genre"]== "Drama"]
likes_drama_data = Drama_data["YoutubeLikes"].sum()
values.append(likes_drama_data)
values
# Out:
# [172250, 177241, 143312, 401873, 279077]

# %%
values.max()

# %% [markdown]
# ### from the Above List  ACTION  genre of movies typically sees more YouTube likes

# %% [markdown]
# ### BoxPLot of each genre of movies

# %%
data.boxplot(by='Genre',column=['YoutubeLikes'],grid=True,color = 'r')
# Out:
# <AxesSubplot:title={'center':'YoutubeLikes'}, xlabel='Genre'>

# %% [markdown]
# ### 11. Which of the variables among Budget, BoxOfficeCollection, YoutubeView, YoutubeLikes, YoutubeDislikes are highly correlated? Note: Draw pair plot or heatmap.

# %%
 dataplot = sns.pairplot(data,vars=['Budget','BoxOfficeCollection','YoutubeViews','YoutubeLikes','YoutubeDislikes'])

# %%
data.corr()
# Out:
#                          SlNo    Budget  BoxOfficeCollection  YoutubeViews  \
# SlNo                 1.000000  0.116899             0.036908      0.025027
# Budget               0.116899  1.000000             0.650401      0.589038
# BoxOfficeCollection  0.036908  0.650401             1.000000      0.588632
# YoutubeViews         0.025027  0.589038             0.588632      1.000000
# YoutubeLikes         0.018163  0.608916             0.682517      0.884055
# YoutubeDislikes      0.035949  0.665343             0.623941      0.846739
# Year                 0.132755  0.062069             0.011673      0.280666
# month                0.219954  0.258457             0.280943      0.289593
# ROI                  0.037314  0.072050             0.585042      0.252847
#
#                      YoutubeLikes  YoutubeDislikes      Year     month  \
# SlNo                     0.018163         0.035949  0.132755  0.219954
# Budget                   0.608916         0.665343  0.062069  0.258457
# ...

# %% [markdown]
# ### From this Above data YoutubeViews and YoutubeLikes Have the Highest Correlation i.e 0.884055

# %% [markdown]
# ### 12. During 2013−2015 period, highlight the genre of movies and their box office collection? Visualize with best fit graph.

# %%
plt.bar(data['Genre'],data['BoxOfficeCollection'])
plt.xlabel('Genre')
plt.ylabel('BoxOfficeCollection')
plt.title('Genre of movies and theirbox office collection')
# Out:
# Text(0.5, 1.0, 'Genre of movies and theirbox office collection')

# %% [markdown]
# ### 13.visualize the Budget and Box office collection based on Genre

# %%
x=data["Genre"]
y1=data["Budget"]
plt.bar(x,y1)
plt.xlabel("Genre",color='r')
plt.ylabel("Budget",color = 'r')
plt.title("Budget based on Genre",color='r')
# Out:
# Text(0.5, 1.0, 'Budget based on Genre')

# %%
x=data["Genre"]
y2=data["BoxOfficeCollection"]
plt.bar(x,y2)
plt.xlabel("Genre",color='r')
plt.ylabel("BoxOfficeCollection",color = 'r')
plt.title("BoxOfficeCollection based on Genre",color='r')
# Out:
# Text(0.5, 1.0, 'BoxOfficeCollection based on Genre')

# %%
plt.bar(x,y2,label="BoxOfficeCollection")
plt.bar(x,y1,label = "Budget")
plt.xlabel("Genre",color ='r')
plt.ylabel("Movie creation budget",color ='r')
plt.title("Budget and Box office collection based on Genre",color ='r')
plt.legend()
plt.show()

# %% [markdown]
# ### 14. Find the distribution of movie budget for every Genre.

# %%
comedy_data["Budget"].hist()
plt.xlabel("Comedy",color ='r')
plt.ylabel("Budget",color ='r')
plt.title("Distribution of Movie Budget for Comedy",color = 'r')
# Out:
# Text(0.5, 1.0, 'Distribution of Movie Budget for Comedy')

# %%
Drama_data["Budget"].hist()
plt.xlabel("Drama",color ='r')
plt.ylabel("Budget",color ='r')
plt.title("Distribution of Movie Budget for Drama",color = 'r')
# Out:
# Text(0.5, 1.0, 'Distribution of Movie Budget for Drama')

# %%
thriller_data["Budget"].hist()
plt.xlabel("Thriller",color ='r')
plt.ylabel("Budget",color ='r')
plt.title("Distribution of Movie Budget for Thriller",color = 'r')
# Out:
# Text(0.5, 1.0, 'Distribution of Movie Budget for Thriller')

# %%
romance_data["Budget"].hist()
plt.xlabel("Romance",color ='r')
plt.ylabel("Budget",color ='r')
plt.title("Distribution of Movie Budget for Romance",color = 'r')
# Out:
# Text(0.5, 1.0, 'Distribution of Movie Budget for Romance')

# %%
action_data["Budget"].hist()
plt.xlabel("Action",color ='r')
plt.ylabel("Budget",color ='r')
plt.title("Distribution of Movie Budget for Action",color = 'r')
# Out:
# Text(0.5, 1.0, 'Distribution of Movie Budget for Action')

# %% [markdown]
# ### 15.During 2013−2015, find the number of movies released in every year. Also, visualize with best fit graph

# %%
data["Year"].value_counts()
# Out:
# 2014    70
# 2013    67
# 2015    12
# Name: Year, dtype: int64

# %% [markdown]
# ### we can see that maximum movies are released in 2014
# #### in 2013 -> number of movies = 67
# #### in 2014 -> number of movies = 70
# #### in 2015 -> number of movies = 12

# %%
data['Year'].value_counts().plot(kind='bar')
plt.xlabel("Year",color ='r')
plt.ylabel("Number of Movies",color ='r')
plt.title("Distribution of number of movies Over Years",color ='r')
# Out:
# Text(0.5, 1.0, 'Distribution of number of movies Over Years')
